# %%
import pandas as pd
import numpy
pd.options.display.max_columns = 99

# %%
cars1=pd.read_csv("imports-85.data")
cars1
# Out:
#      3    ?  alfa-romero     gas    std   two  convertible  rwd  front  88.60  \
# 0    3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6
# 1    1    ?  alfa-romero     gas    std   two    hatchback  rwd  front   94.5
# 2    2  164         audi     gas    std  four        sedan  fwd  front   99.8
# 3    2  164         audi     gas    std  four        sedan  4wd  front   99.4
# 4    2    ?         audi     gas    std   two        sedan  fwd  front   99.8
# 5    1  158         audi     gas    std  four        sedan  fwd  front  105.8
# 6    1    ?         audi     gas    std  four        wagon  fwd  front  105.8
# 7    1  158         audi     gas  turbo  four        sedan  fwd  front  105.8
# 8    0    ?         audi     gas  turbo   two    hatchback  4wd  front   99.5
# 9    2  192          bmw     gas    std   two        sedan  rwd  front  101.2
# 10   0  192          bmw     gas    std  four        sedan  rwd  front  101.2
# ...

# %%
import re
sand='''1. symboling: -3, -2, -1, 0, 1, 2, 3.
2. normalized-losses: continuous from 65 to 256.
3. make:
alfa-romero, audi, bmw, chevrolet, dodge, honda,
isuzu, jaguar, mazda, mercedes-benz, mercury,
mitsubishi, nissan, peugot, plymouth, porsche,
renault, saab, subaru, toyota, volkswagen, volvo

4. fuel-type: diesel, gas.
5. aspiration: std, turbo.
6. num-of-doors: four, two.
7. body-style: hardtop, wagon, sedan, hatchback, convertible.
8. drive-wheels: 4wd, fwd, rwd.
9. engine-location: front, rear.
10. wheel-base: continuous from 86.6 120.9.
11. length: continuous from 141.1 to 208.1.
12. width: continuous from 60.3 to 72.3.
13. height: continuous from 47.8 to 59.8.
14. curb-weight: continuous from 1488 to 4066.
15. engine-type: dohc, dohcv, l, ohc, ohcf, ohcv, rotor.
16. num-of-cylinders: eight, five, four, six, three, twelve, two.
17. engine-size: continuous from 61 to 326.
18. fuel-system: 1bbl, 2bbl, 4bbl, idi, mfi, mpfi, spdi, spfi.
19. bore: continuous from 2.54 to 3.94.
20. stroke: continuous from 2.07 to 4.17.
21. compression-ratio: continuous from 7 to 23.
22. horsepower: continuous from 48 to 288.
23. peak-rpm: continuous from 4150 to 6600.
24. city-mpg: continuous from 13 to 49.
25. highway-mpg: continuous from 16 to 54.
26. price: continuous from 5118 to 45400.'''

# %%
column=[]
sand=sand.split("\n")
for each in sand:
    c1=re.sub("[ 01234567809,.]","",each.split(":")[0])
    column.append(c1)
del(column[3:8])

# %%
cars=pd.read_csv("imports-85.data",names=column)

# %%
cars
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# 5            2                 ?         audi       gas        std
# 6            1               158         audi       gas        std
# 7            1                 ?         audi       gas        std
# 8            1               158         audi       gas      turbo
# 9            0                 ?         audi       gas      turbo
# 10           2               192          bmw       gas        std
# 11           0               192          bmw       gas        std
# 12           0               188          bmw       gas        std
# ...

# %% [markdown]
# as we observe the difference between the two data frames is the 1 column is printed twice so we can remove one of them

# %%
cars=cars.drop(cars.index[0])
cars.reset_index()
# Out:
#      index  symboling normalized-losses         make fuel-type aspiration  \
# 0        1          3                 ?  alfa-romero       gas        std
# 1        2          1                 ?  alfa-romero       gas        std
# 2        3          2               164         audi       gas        std
# 3        4          2               164         audi       gas        std
# 4        5          2                 ?         audi       gas        std
# 5        6          1               158         audi       gas        std
# 6        7          1                 ?         audi       gas        std
# 7        8          1               158         audi       gas      turbo
# 8        9          0                 ?         audi       gas      turbo
# 9       10          2               192          bmw       gas        std
# 10      11          0               192          bmw       gas        std
# 11      12          0               188          bmw       gas        std
# ...

# %%
cars.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
# 5        sedan          fwd           front        99.8   177.3   66.3
#
# ...

# %%
cars=cars.replace(to_replace="?",value=numpy.nan)

# %%
cars_int=cars[['normalized-losses', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']]

# %%
cars_int=cars_int.astype(float)
cars_int = cars_int.fillna(cars_int.mean())

# %%
pricecol=cars_int['price']
cars_int.dropna(subset=['price'])
cars_int.apply(lambda x :(x-min(x))/(max(x)-min(x)))
# Out:
#      normalized-losses  wheel-base    length     width    height  curb-weight  \
# 1             0.298429    0.058309  0.413433  0.316667  0.083333     0.411171
# 2             0.298429    0.230321  0.449254  0.433333  0.383333     0.517843
# 3             0.518325    0.384840  0.529851  0.491667  0.541667     0.329325
# 4             0.518325    0.373178  0.529851  0.508333  0.541667     0.518231
# 5             0.298429    0.384840  0.540299  0.500000  0.441667     0.395268
# 6             0.486911    0.559767  0.770149  0.925000  0.658333     0.525989
# 7             0.298429    0.559767  0.770149  0.925000  0.658333     0.568658
# 8             0.486911    0.559767  0.770149  0.925000  0.675000     0.619860
# 9             0.298429    0.376093  0.553731  0.633333  0.350000     0.607060
# 10            0.664921    0.425656  0.532836  0.375000  0.541667     0.351823
# 11            0.664921    0.425656  0.532836  0.375000  0.541667     0.351823
# ...

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
def knn_train_test(train_col,target_col,df):
    knn=KNeighborsRegressor()
    numpy.random.seed(1)
    shuffled_index=numpy.random.permutation(df.index)
    rand_df=df.reindex(shuffled_index)
    train_df=rand_df.iloc[0:int(len(rand_df))// 2]
    test_df=rand_df.iloc[int(len(rand_df))// 2:]
    knn.fit(train_df[[train_col]],train_df[[target_col]])
    predictions=knn.predict(test_df[[train_col]])
    mse=mean_squared_error(test_df[[target_col]],predictions)
    rmse=mse**0.5
    return rmse
rmse_results = {}
train_cols = cars_int.columns.drop('price')


for col in train_cols:
    rmse_val = knn_train_test(col, "price", cars_int)
    rmse_results[col] = rmse_val
    
rmse_results_series = pd.Series(rmse_results)
rmse_results_series.sort_values()
# Out:
# curb-weight          4210.485622
# highway-mpg          4497.207768
# width                5051.820124
# horsepower           5107.021448
# length               5179.716755
# city-mpg             5675.161063
# wheel-base           5727.869929
# compression-ratio    6242.230467
# stroke               7140.846748
# normalized-losses    7628.213924
# peak-rpm             7664.671145
# bore                 7680.010031
# height               8081.534941
# dtype: float64

# %%
def knn_train_test1(train_col,target_col,df):
    
    numpy.random.seed(1)
    shuffled_index=numpy.random.permutation(df.index)
    rand_df=df.reindex(shuffled_index)
    train_df=rand_df.iloc[0:int(len(rand_df))// 2]
    test_df=rand_df.iloc[int(len(rand_df))// 2:]
    k_values = [1,3,5,7,9]
    k_rmses = {}
    for k in k_values:
        knn=KNeighborsRegressor(n_neighbors=k)
        knn.fit(train_df[[train_col]],train_df[[target_col]])
        predictions=knn.predict(test_df[[train_col]])
        mse=mean_squared_error(test_df[[target_col]],predictions)
        rmse=mse**0.5

        k_rmses[k]=rmse
    return k_rmses
k_rmse_results = {}

# For each column (minus `price`), train a model, return RMSE value
# and add to the dictionary `rmse_results`.
train_cols = cars_int.columns.drop('price')
for col in train_cols:
    rmse_val = knn_train_test1(col, 'price', cars_int)
    k_rmse_results[col] = rmse_val

k_rmse_results
# Out:
# {'bore': {1: 12172.111412008842,
#   3: 8578.9366422435032,
#   5: 7680.0100312264776,
#   7: 7330.4732327941774,
#   9: 6887.7609323633178},
#  'city-mpg': {1: 7769.5552138751109,
#   3: 5171.8546582168465,
#   5: 5675.1610632277179,
#   7: 5618.7679099483312,
#   9: 5117.2296636149695},
#  'compression-ratio': {1: 7279.4235780795843,
#   3: 6995.6348022238026,
#   5: 6242.2304674559446,
#   7: 6838.9454145668851,
#   9: 7145.6850673578647},
#  'curb-weight': {1: 5884.9166112907733,
#   3: 4301.3150385632498,
#   5: 4210.4856220041938,
#   7: 4079.9961780918616,
#   9: 4367.8828900878407},
#  'height': {1: 9888.3163859828564,
#   3: 7757.3843038519908,
#   5: 8081.5349409419314,
#   7: 7570.1618731589688,
#   9: 7494.0549817402043},
#  'highway-mpg': {1: 4987.4227498349856,
#   3: 5187.2305685459269,
#   5: 4497.2077679128079,
#   7: 4541.4077778346891,
#   9: 4560.5602547623175},
#  'horsepower': {1: 5178.2065753826655,
#   3: 5310.4223748338563,
#   5: 5107.0214481946059,
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

for k,v in k_rmse_results.items():
    x = list(v.keys())
    y = list(v.values())
    
    plt.plot(x,y)
    plt.xlabel('k value')
    plt.ylabel('RMSE')

# %%
def knn_train_test2(train_col,target_col,df):
    
    numpy.random.seed(1)
    shuffled_index=numpy.random.permutation(df.index)
    rand_df=df.reindex(shuffled_index)
    train_df=rand_df.iloc[0:int(len(rand_df))// 2]
    test_df=rand_df.iloc[int(len(rand_df))// 2:]
    k_values = [5]
    k_rmses = {}
    for k in k_values:
        knn=KNeighborsRegressor(n_neighbors=k)
        knn.fit(train_df[train_col],train_df[target_col])
        predictions=knn.predict(test_df[train_col])
        mse=mean_squared_error(test_df[target_col],predictions)
        rmse=mse**0.5

        k_rmses[k]=rmse
    return k_rmses

k_rmse_results = {}

two_best_features = ['horsepower', 'width']
rmse_val = knn_train_test2(two_best_features, 'price', cars_int)
k_rmse_results["two best features"] = rmse_val

three_best_features = ['horsepower', 'width', 'curb-weight']
rmse_val = knn_train_test2(three_best_features, 'price', cars_int)
k_rmse_results["three best features"] = rmse_val

four_best_features = ['horsepower', 'width', 'curb-weight', 'city-mpg']
rmse_val = knn_train_test2(four_best_features, 'price', cars_int)
k_rmse_results["four best features"] = rmse_val

five_best_features = ['horsepower', 'width', 'curb-weight' , 'city-mpg' , 'highway-mpg']
rmse_val = knn_train_test2(five_best_features, 'price', cars_int)
k_rmse_results["five best features"] = rmse_val

six_best_features = ['horsepower', 'width', 'curb-weight' , 'city-mpg' , 'highway-mpg', 'length']
rmse_val = knn_train_test2(six_best_features, 'price', cars_int)
k_rmse_results["six best features"] = rmse_val

k_rmse_results
# Out:
# {'five best features': {5: 4000.4265503027027},
#  'four best features': {5: 3999.7898143863445},
#  'six best features': {5: 4001.7344950259394},
#  'three best features': {5: 3998.2755656375948},
#  'two best features': {5: 4999.2574374420137}}

# %%
def knn_train_test(train_cols, target_col, df):
    numpy.random.seed(1)
    
    # Randomize order of rows in data frame.
    shuffled_index = numpy.random.permutation(df.index)
    rand_df = df.reindex(shuffled_index)

    # Divide number of rows in half and round.
    last_train_row = int(len(rand_df) / 2)
    
    # Select the first half and set as training set.
    # Select the second half and set as test set.
    train_df = rand_df.iloc[0:last_train_row]
    test_df = rand_df.iloc[last_train_row:]
    
    k_values = [i for i in range(1, 25)]
    k_rmses = {}
    
    for k in k_values:
        # Fit model using k nearest neighbors.
        knn = KNeighborsRegressor(n_neighbors=k)
        knn.fit(train_df[train_cols], train_df[target_col])

        # Make predictions using model.
        predicted_labels = knn.predict(test_df[train_cols])

        # Calculate and return RMSE.
        mse = mean_squared_error(test_df[target_col], predicted_labels)
        rmse = numpy.sqrt(mse)
        
        k_rmses[k] = rmse
    return k_rmses

k_rmse_results = {}

three_best_features = ['horsepower', 'width', 'curb-weight']
rmse_val = knn_train_test(three_best_features, 'price', cars_int)
k_rmse_results["three best features"] = rmse_val

four_best_features = ['horsepower', 'width', 'curb-weight', 'city-mpg']
rmse_val = knn_train_test(four_best_features, 'price', cars_int)
k_rmse_results["four best features"] = rmse_val

five_best_features = ['horsepower', 'width', 'curb-weight' , 'city-mpg' , 'highway-mpg']
rmse_val = knn_train_test(five_best_features, 'price', cars_int)
k_rmse_results["five best features"] = rmse_val

k_rmse_results
# Out:
# {'five best features': {1: 3918.0523330342457,
#   2: 4591.9570650783307,
#   3: 4184.7671384773294,
#   4: 4091.5196001309087,
#   5: 4000.4265503027027,
#   6: 3990.3150333479111,
#   7: 4004.8647521253483,
#   8: 4153.9378906508982,
#   9: 4180.4133140178119,
#   10: 4345.0405029965495,
#   11: 4454.4379624753274,
#   12: 4485.50266040519,
#   13: 4583.8564509254784,
#   14: 4630.2067123306315,
#   15: 4681.5702831521357,
#   16: 4719.3893648490557,
#   17: 4770.2374116449228,
#   18: 4798.5224030130212,
#   19: 4767.3979477986495,
#   20: 4838.8666735452643,
#   21: 4898.2663100557393,
#   22: 4945.478950474434,
#   23: 4986.2213731424727,
#   24: 5029.4648077934053},
#  'four best features': {1: 3925.7146628106916,
#   2: 4594.5868681518459,
#   3: 4184.9596384425304,
#   4: 4087.2797264531573,
#   5: 3999.7898143863445,
#   6: 3990.5494304432741,
#   7: 4004.6328120224143,
#   8: 4154.3853472945166,
#   9: 4180.5449505559018,
#   10: 4345.2113262688863,
# ...
